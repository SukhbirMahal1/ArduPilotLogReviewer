# %%
import ardupilot_log_reviewer as ArduPilotLogReviewer

filedate = "2026-03-26"
filepath = f"logs/{filedate}.BIN"
MOTOR_RCOU_CH = [10, 11, 12]

filedate = "2026-03-26"
filepath = f"logs/{filedate}.BIN"
MOTOR_RCOU_CH = [10, 11, 12]

reviewer = ArduPilotLogReviewer(
    filedate=filedate,
    filepath=filepath,
    MOTOR_RCOU_CH=MOTOR_RCOU_CH,
    auto_detect_flight=False,
    T_MIN=2675,
    T_MAX=2800,
    ESC_CONT_A=70,
    ESC_BURST_A=80,
    save_plots=True,
    show_plots=False
)

reviewer.plot_att()
reviewer.plot_vibes()
reviewer.plot_rcou()
reviewer.plot_esc()
reviewer.plot_bat()
reviewer.plot_imus()
reviewer.plot_powr()
reviewer.plot_compass_interference()
reviewer.plot_gps()
reviewer.plot_baro()
reviewer.save_summary()
reviewer.plot_filter_review()
reviewer.plot_filter_review(tune=True, notch_freq=80, bw=80/2, att=10)
# Out:
# Parsing logs/2026-03-26.BIN...
# Flight Window: 2675.0s - 2800.0s (Duration: 125.0s)
# Plotting ATT...
# Saving CSV ATT_2026-03-26.csv...
# Saving Plot ATT_2026-03-26.png...
# Plotting VIBE...
# Saving CSV VIBE[0]_2026-03-26.csv...
# Saving CSV VIBE[1]_2026-03-26.csv...
# Saving CSV VIBE[2]_2026-03-26.csv...
# Saving Plot VIBE_2026-03-26.png...
# Plotting RCOU...
# Saving CSV RCOU_2026-03-26.csv...
# Saving Plot RCOU_2026-03-26.png...
# Plotting ESC...
# Saving CSV ESC[9].RPM_2026-03-26.csv...
# Saving CSV ESC[10].RPM_2026-03-26.csv...
# Saving CSV ESC[11].RPM_2026-03-26.csv...
# Saving Plot ESC_2026-03-26.png...
# Plotting BAT...
# Saving CSV BAT[0]_2026-03-26.csv...
# Saving Plot BAT_2026-03-26.png...
# Plotting IMU...
# Saving CSV IMU[0]_2026-03-26.csv...
# Saving CSV IMU[1]_2026-03-26.csv...
# Saving CSV IMU[2]_2026-03-26.csv...
# Saving Plot IMU_2026-03-26.png...
# Plotting POWR...
# Saving CSV POWR_2026-03-26.csv...
# Saving Plot POWR_2026-03-26.png...
# Plotting MAG...
# Saving CSV MAG[0]_2026-03-26.csv...
# Saving CSV MAG[1]_2026-03-26.csv...
# Saving Plot MAG_2026-03-26.png...
# Plotting GPS...
# Saving CSV GPS[0]_2026-03-26.csv...
# Saving Plot GPS_2026-03-26.png...
# Plotting BARO...
# Saving CSV BARO[0]_2026-03-26.csv...
# Saving CSV BARO[1]_2026-03-26.csv...
# Saving Plot BARO_2026-03-26.png...
# Generating Summary...
# Summary Saved To summaries/2026-03-26/SUMMARY_2026-03-26.txt
# Filter Review...
# Saving CSV FILTER_REVIEW_TUNE_False_2026-03-26.csv...
# Saving Plot FILTER_REVIEW_TUNE_False_2026-03-26.png...
# Filter Review...
# Saving CSV FILTER_REVIEW_TUNE_True_2026-03-26.csv...
# Saving Plot FILTER_REVIEW_TUNE_True_2026-03-26.png...
