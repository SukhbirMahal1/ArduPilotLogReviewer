# %%
from ardupilot_log_reviewer.ArduPilotLogReviewer import ArduPilotLogReviewer

filedate = "2026-03-26"
filepath = f"logs/{filedate}.BIN"
MOTOR_RCOU_CH = [10, 11, 12]

reviewer = ArduPilotLogReviewer(
    filedate=filedate,
    filepath=filepath,
    MOTOR_RCOU_CH=MOTOR_RCOU_CH,
    auto_detect_flight=False,
    T_MIN=2675,
    T_MAX=2800,
    save_plots=True,
    show_plots=True
)

reviewer.plot_att()
reviewer.plot_vibes()
reviewer.plot_rcou()
reviewer.plot_esc()
reviewer.plot_bat()
reviewer.plot_imus()
reviewer.plot_powr()
reviewer.plot_compass_interference()
reviewer.plot_gps()
reviewer.plot_baro()
reviewer.save_summary()
reviewer.plot_filter_review()
reviewer.plot_filter_review(tune=True, notch_freq=80, bw=80/2, att=10)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 7
#       4 filepath = f"examples/logs/{filedate}.BIN"
#       5 MOTOR_RCOU_CH = [10, 11, 12]
# ----> 7 reviewer = ArduPilotLogReviewer(
#       8     filedate=filedate,
#       9     filepath=filepath,
#      10     MOTOR_RCOU_CH=MOTOR_RCOU_CH,
#      11     auto_detect_flight=False,
#      12     T_MIN=2675,
#      13     T_MAX=2800,
#      14     save_plots=True,
#      15     show_plots=True
#      16 )
#      18 reviewer.plot_att()
#      19 reviewer.plot_vibes()
#
# File ~\Documents\Education\Part IV Aeronautics and Astronautics\FEEG6013 Group Design Project\report\ArduPilotLogReviewer\src\ardupilot_log_reviewer\ArduPilotLogReviewer.py:30, in ArduPilotLogReviewer.__init__(self, filedate, filepath, MOTOR_RCOU_CH, auto_detect_flight, T_MIN, T_MAX, save_plots, show_plots)
#      27 os.makedirs(f'summaries/{self.filedate}', exist_ok=True)
#      29 # parse
# ---> 30 self.mavlog = MavLog(filepath=filepath)
#      31 self.mavlog.parse()
#      32 print(f'Parsing {filepath}...')
#
# File c:\Users\sukhi\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymavlog\core.py:300, in MavLog.__init__(self, filepath, messages_to_ignore, types, to_datetime, map_columns, max_rate_hz)
#     291 def __init__(
#     292     self,
#     293     filepath: str,
#    (...)
#     298     max_rate_hz: float = None,
#     299 ):
# --> 300     super().__init__(
#     301         filepath=filepath,
#     302         messages_to_ignore=messages_to_ignore,
#     303         types=types,
#     304         to_datetime=to_datetime,
#     305         map_columns=map_columns,
#     306         max_rate_hz=max_rate_hz,
#     307     )
#     309     self._set_parsed_data(types)
#
# File c:\Users\sukhi\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymavlog\core.py:203, in MavLogBase.__init__(self, filepath, messages_to_ignore, types, to_datetime, map_columns, max_rate_hz)
#     193 def __init__(
#     194     self,
#     195     filepath: str,
#    (...)
#     200     max_rate_hz: float = None,
#     201 ):
#     202     self._messages_ignore = messages_to_ignore
# --> 203     self._mlog: mavutil.mavserial = mavutil.mavlink_connection(filepath)
#     205     self._parsed_data: t.Dict[str, MavLinkMessageSeries] = {}
#     206     self._msg_count = 0
#
# File c:\Users\sukhi\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymavlink\mavutil.py:2055, in mavlink_connection(device, baud, source_system, source_component, planner_format, write, append, robust_parsing, notimestamps, input, dialect, autoreconnect, zero_time_base, retries, use_native, force_connected, progress_callback, udp_timeout, **opts)
#    2052 if device.lower().endswith('.bin') or device.lower().endswith('.px4log'):
#    2053     # support dataflash logs
#    2054     from pymavlink import DFReader
# -> 2055     m = DFReader.DFReader_binary(device, zero_time_base=zero_time_base, progress_callback=progress_callback)
#    2056     mavfile_global = m
#    2057     return m
#
# File c:\Users\sukhi\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymavlink\DFReader.py:1102, in DFReader_binary.__init__(self, filename, zero_time_base, progress_callback)
#    1100 DFReader.__init__(self)
#    1101 # read the whole file into memory for simplicity
# -> 1102 self.filehandle = open(filename, 'rb')
#    1103 self.filehandle.seek(0, 2)
#    1104 self.data_len = self.filehandle.tell()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'examples/logs/2026-03-26.BIN'
