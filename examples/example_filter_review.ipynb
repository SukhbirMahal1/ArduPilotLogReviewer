# %%
from ardupilot_log_reviewer import ArduPilotLogReviewer

filedate = "2026-03-27"
filepath = f"logs/{filedate}.BIN"
MOTOR_RCOU_CH = [10, 11, 12]

reviewer = ArduPilotLogReviewer(
    filedate=filedate,
    filepath=filepath,
    MOTOR_RCOU_CH=MOTOR_RCOU_CH,
)

reviewer.plot_filter_review()
reviewer.plot_filter_review(tune=True, notch_freq=80, notch_bandwith=80/2, notch_att=10)
reviewer.plot_filter_review(autotune=True, notch_att=10)
# Out:
# Parsing logs/2026-03-27.BIN...
# Flight Window Detected: 355.1s - 3239.3s (Duration: 2884.3s)
# Plotting Filter Review...
# Saving Plot FILTER_REVIEW_TUNE_False_2026-03-27.png...
# Plotting Filter Review...
# Saving Plot FILTER_REVIEW_TUNE_True_2026-03-27.png...
# Plotting Filter Review...
# Detected Motor Frequency: 70.5 Hz
# Saving Plot FILTER_REVIEW_AUTOTUNE_2026-03-27.png...
