# %%
from ardupilot_log_reviewer import ArduPilotLogReviewer

filedate = "2026-04-22"
filepath = f"logs/{filedate}.BIN"
MOTOR_RCOU_CH = [10, 11, 12]

reviewer = ArduPilotLogReviewer(
    filedate=filedate,
    filepath=filepath,
    MOTOR_RCOU_CH=MOTOR_RCOU_CH,
    auto_detect_flight=False,
    T_MIN=425,
    T_MAX=525,
    ESC_CONT_A=70,
    ESC_BURST_A=80,
    save_plots=True,
    show_plots=True,
    verbose=True
)

reviewer.plot_att()
reviewer.plot_vibes()
reviewer.plot_rcou()
reviewer.plot_esc()
reviewer.plot_bat()
reviewer.plot_imus()
reviewer.plot_powr()
reviewer.plot_compass_interference()
reviewer.plot_gps()
reviewer.plot_baro()
reviewer.save_summary()
# Out:
# C:\Users\sukhi\Documents\Education\Part IV Aeronautics and Astronautics\FEEG6013 Group Design Project\report\ArduPilotLogReviewer\src\ardupilot_log_reviewer\ArduPilotLogReviewer.py:84: SyntaxWarning: invalid escape sequence '\c'
#   plt.ylabel('Roll [$^\circ$]')
# C:\Users\sukhi\Documents\Education\Part IV Aeronautics and Astronautics\FEEG6013 Group Design Project\report\ArduPilotLogReviewer\src\ardupilot_log_reviewer\ArduPilotLogReviewer.py:85: SyntaxWarning: invalid escape sequence '\c'
#   plt.title(f'RMSE: {rmse_roll:.1f}$^\circ$')
# C:\Users\sukhi\Documents\Education\Part IV Aeronautics and Astronautics\FEEG6013 Group Design Project\report\ArduPilotLogReviewer\src\ardupilot_log_reviewer\ArduPilotLogReviewer.py:93: SyntaxWarning: invalid escape sequence '\c'
#   plt.ylabel('Pitch [$^\circ$]')
# C:\Users\sukhi\Documents\Education\Part IV Aeronautics and Astronautics\FEEG6013 Group Design Project\report\ArduPilotLogReviewer\src\ardupilot_log_reviewer\ArduPilotLogReviewer.py:94: SyntaxWarning: invalid escape sequence '\c'
#   plt.title(f'RMSE: {rmse_pitch:.1f}$^\circ$')
# C:\Users\sukhi\Documents\Education\Part IV Aeronautics and Astronautics\FEEG6013 Group Design Project\report\ArduPilotLogReviewer\src\ardupilot_log_reviewer\ArduPilotLogReviewer.py:102: SyntaxWarning: invalid escape sequence '\c'
#   plt.ylabel('Yaw [$^\circ$]')
# C:\Users\sukhi\Documents\Education\Part IV Aeronautics and Astronautics\FEEG6013 Group Design Project\report\ArduPilotLogReviewer\src\ardupilot_log_reviewer\ArduPilotLogReviewer.py:103: SyntaxWarning: invalid escape sequence '\c'
#   plt.title(f'RMSE: {rmse_yaw:.1f}$^\circ$')
# C:\Users\sukhi\Documents\Education\Part IV Aeronautics and Astronautics\FEEG6013 Group Design Project\report\ArduPilotLogReviewer\src\ardupilot_log_reviewer\ArduPilotLogReviewer.py:150: SyntaxWarning: invalid escape sequence '\m'
#   plt.ylabel('PWM [$\mu$s]')
# Parsing logs/2026-04-22.BIN...
# Flight Window: 425.0s - 525.0s (Duration: 100.0s)
# Plotting ATT...
# Saving CSV ATT_2026-04-22.csv...
# Saving Plot ATT_2026-04-22.png...
# Plotting VIBE...
# Saving CSV VIBE[0]_2026-04-22.csv...
# Saving CSV VIBE[1]_2026-04-22.csv...
# Saving CSV VIBE[2]_2026-04-22.csv...
# Saving Plot VIBE_2026-04-22.png...
# Plotting RCOU...
# Saving CSV RCOU_2026-04-22.csv...
# Saving Plot RCOU_2026-04-22.png...
# Plotting ESC...
# Saving CSV ESC[9].RPM_2026-04-22.csv...
# Saving CSV ESC[10].RPM_2026-04-22.csv...
# Saving CSV ESC[11].RPM_2026-04-22.csv...
# Saving Plot ESC_2026-04-22.png...
# Plotting BAT...
# Saving CSV BAT[0]_2026-04-22.csv...
# Saving Plot BAT_2026-04-22.png...
# Plotting IMU...
# Saving CSV IMU[0]_2026-04-22.csv...
# Saving CSV IMU[1]_2026-04-22.csv...
# Saving CSV IMU[2]_2026-04-22.csv...
# Saving Plot IMU_2026-04-22.png...
# Plotting POWR...
# Saving CSV POWR_2026-04-22.csv...
# Saving Plot POWR_2026-04-22.png...
# Plotting MAG...
# Saving CSV MAG[0]_2026-04-22.csv...
# Saving CSV MAG[1]_2026-04-22.csv...
# Saving Plot MAG_2026-04-22.png...
# Plotting GPS...
# Saving CSV GPS[0]_2026-04-22.csv...
# Saving Plot GPS_2026-04-22.png...
# Plotting BARO...
# Saving CSV BARO[0]_2026-04-22.csv...
# Saving CSV BARO[1]_2026-04-22.csv...
# Saving Plot BARO_2026-04-22.png...
# Generating Summary...
# Saving SUMMARY_2026-04-22.txt...
