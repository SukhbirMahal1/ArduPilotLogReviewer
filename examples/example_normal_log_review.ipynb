# %%
from ardupilot_log_reviewer import ArduPilotLogReviewer

filedate = "2026-03-27"
filepath = f"logs/{filedate}.BIN"
MOTOR_RCOU_CH = [10, 11, 12]

reviewer = ArduPilotLogReviewer(
    filedate=filedate,
    filepath=filepath,
    MOTOR_RCOU_CH=MOTOR_RCOU_CH,
    auto_detect_flight=False,
    T_MIN=2675,
    T_MAX=2800,
    ESC_CONT_A=70,
    ESC_BURST_A=80,
    save_plots=True,
    show_plots=True,
    verbose=True
)

reviewer.plot_att()
reviewer.plot_vibes()
reviewer.plot_rcou()
reviewer.plot_esc()
reviewer.plot_bat()
reviewer.plot_imus()
reviewer.plot_powr()
reviewer.plot_compass_interference()
reviewer.plot_gps()
reviewer.plot_baro()
reviewer.save_summary()
# Out:
# C:\Users\sukhi\Documents\Education\Part IV Aeronautics and Astronautics\FEEG6013 Group Design Project\report\ArduPilotLogReviewer\src\ardupilot_log_reviewer\ArduPilotLogReviewer.py:99: SyntaxWarning: invalid escape sequence '\c'
#   plt.ylabel('Roll [$^\circ$]')
# C:\Users\sukhi\Documents\Education\Part IV Aeronautics and Astronautics\FEEG6013 Group Design Project\report\ArduPilotLogReviewer\src\ardupilot_log_reviewer\ArduPilotLogReviewer.py:100: SyntaxWarning: invalid escape sequence '\c'
#   plt.title(f'RMSE: {rmse_roll:.1f}$^\circ$')
# C:\Users\sukhi\Documents\Education\Part IV Aeronautics and Astronautics\FEEG6013 Group Design Project\report\ArduPilotLogReviewer\src\ardupilot_log_reviewer\ArduPilotLogReviewer.py:108: SyntaxWarning: invalid escape sequence '\c'
#   plt.ylabel('Pitch [$^\circ$]')
# C:\Users\sukhi\Documents\Education\Part IV Aeronautics and Astronautics\FEEG6013 Group Design Project\report\ArduPilotLogReviewer\src\ardupilot_log_reviewer\ArduPilotLogReviewer.py:109: SyntaxWarning: invalid escape sequence '\c'
#   plt.title(f'RMSE: {rmse_pitch:.1f}$^\circ$')
# C:\Users\sukhi\Documents\Education\Part IV Aeronautics and Astronautics\FEEG6013 Group Design Project\report\ArduPilotLogReviewer\src\ardupilot_log_reviewer\ArduPilotLogReviewer.py:117: SyntaxWarning: invalid escape sequence '\c'
#   plt.ylabel('Yaw [$^\circ$]')
# C:\Users\sukhi\Documents\Education\Part IV Aeronautics and Astronautics\FEEG6013 Group Design Project\report\ArduPilotLogReviewer\src\ardupilot_log_reviewer\ArduPilotLogReviewer.py:118: SyntaxWarning: invalid escape sequence '\c'
#   plt.title(f'RMSE: {rmse_yaw:.1f}$^\circ$')
# C:\Users\sukhi\Documents\Education\Part IV Aeronautics and Astronautics\FEEG6013 Group Design Project\report\ArduPilotLogReviewer\src\ardupilot_log_reviewer\ArduPilotLogReviewer.py:165: SyntaxWarning: invalid escape sequence '\m'
#   plt.ylabel('PWM [$\mu$s]')
# Parsing logs/2026-03-27.BIN...
# Flight Window: 2675.0s - 2800.0s (Duration: 125.0s)
# C:\Users\sukhi\Documents\Education\Part IV Aeronautics and Astronautics\FEEG6013 Group Design Project\report\ArduPilotLogReviewer\src\ardupilot_log_reviewer\ArduPilotLogReviewer.py:99: SyntaxWarning: invalid escape sequence '\c'
#   plt.ylabel('Roll [$^\circ$]')
# C:\Users\sukhi\Documents\Education\Part IV Aeronautics and Astronautics\FEEG6013 Group Design Project\report\ArduPilotLogReviewer\src\ardupilot_log_reviewer\ArduPilotLogReviewer.py:100: SyntaxWarning: invalid escape sequence '\c'
#   plt.title(f'RMSE: {rmse_roll:.1f}$^\circ$')
# C:\Users\sukhi\Documents\Education\Part IV Aeronautics and Astronautics\FEEG6013 Group Design Project\report\ArduPilotLogReviewer\src\ardupilot_log_reviewer\ArduPilotLogReviewer.py:108: SyntaxWarning: invalid escape sequence '\c'
#   plt.ylabel('Pitch [$^\circ$]')
# C:\Users\sukhi\Documents\Education\Part IV Aeronautics and Astronautics\FEEG6013 Group Design Project\report\ArduPilotLogReviewer\src\ardupilot_log_reviewer\ArduPilotLogReviewer.py:109: SyntaxWarning: invalid escape sequence '\c'
#   plt.title(f'RMSE: {rmse_pitch:.1f}$^\circ$')
# C:\Users\sukhi\Documents\Education\Part IV Aeronautics and Astronautics\FEEG6013 Group Design Project\report\ArduPilotLogReviewer\src\ardupilot_log_reviewer\ArduPilotLogReviewer.py:117: SyntaxWarning: invalid escape sequence '\c'
#   plt.ylabel('Yaw [$^\circ$]')
# C:\Users\sukhi\Documents\Education\Part IV Aeronautics and Astronautics\FEEG6013 Group Design Project\report\ArduPilotLogReviewer\src\ardupilot_log_reviewer\ArduPilotLogReviewer.py:118: SyntaxWarning: invalid escape sequence '\c'
#   plt.title(f'RMSE: {rmse_yaw:.1f}$^\circ$')
# C:\Users\sukhi\Documents\Education\Part IV Aeronautics and Astronautics\FEEG6013 Group Design Project\report\ArduPilotLogReviewer\src\ardupilot_log_reviewer\ArduPilotLogReviewer.py:165: SyntaxWarning: invalid escape sequence '\m'
#   plt.ylabel('PWM [$\mu$s]')
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# File ~\Documents\Education\Part IV Aeronautics and Astronautics\FEEG6013 Group Design Project\report\ArduPilotLogReviewer\src\ardupilot_log_reviewer\ArduPilotLogReviewer.py:456, in ArduPilotLogReviewer._get_msg(self, msg)
#     455 try:
# --> 456     df = pd.DataFrame(raw.fields)
#     457 except OverflowError:
#     458     # fallback: convert each column with object dtype to avoid numpy overflow
#
# File c:\Users\sukhi\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymavlog\core.py:152, in MavLinkMessageSeries.fields(self)
#     151 for idx, c in enumerate(self._columns):
# --> 152     fields_np[self._column_alias.get(c, c)] = np.array(
#     153         object=self._fields[self._column_alias.get(c, c)],
#     154         dtype=self._types[idx],
#     155     )
#     156 return fields_np
#
# OverflowError: Python int too large to convert to C long
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 7
#       3 filedate = "2026-03-27"
#       4 filepath = f"logs/{filedate}.BIN"
#       5 MOTOR_RCOU_CH = [10, 11, 12]
#       6
# ----> 7 reviewer = ArduPilotLogReviewer(
#       8     filedate=filedate,
#       9     filepath=filepath,
#      10     MOTOR_RCOU_CH=MOTOR_RCOU_CH,
#
# File ~\Documents\Education\Part IV Aeronautics and Astronautics\FEEG6013 Group Design Project\report\ArduPilotLogReviewer\src\ardupilot_log_reviewer\ArduPilotLogReviewer.py:75, in ArduPilotLogReviewer.__init__(self, filedate, filepath, MOTOR_RCOU_CH, auto_detect_flight, T_MIN, T_MAX, ESC_CONT_A, ESC_BURST_A, save_plots, show_plots, verbose)
#      72     if self.verbose:
#      73         print(f'Flight Window: {self.T_MIN:.1f}s - {self.T_MAX:.1f}s (Duration: {self.T_MAX - self.T_MIN:.1f}s)')
# ---> 75 self.rcou = self._get_msg('RCOU')
#
# File ~\Documents\Education\Part IV Aeronautics and Astronautics\FEEG6013 Group Design Project\report\ArduPilotLogReviewer\src\ardupilot_log_reviewer\ArduPilotLogReviewer.py:466, in ArduPilotLogReviewer._get_msg(self, msg)
#     464     # try to coerce numeric columns
#     465     for col in df.columns:
# --> 466         df[col] = pd.to_numeric(df[col], errors='ignore')
#     468 if msg != 'PARM':
#     469     df = df[(df['TimeUS'] / 1e6 >= self.T_MIN) & (df['TimeUS'] / 1e6 <= self.T_MAX)]
#
# File c:\Users\sukhi\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\tools\numeric.py:183, in to_numeric(arg, errors, downcast, dtype_backend)
#     180     raise ValueError("invalid downcasting method provided")
#     182 if errors not in ("raise", "coerce"):
# --> 183     raise ValueError("invalid error value specified")
#     185 check_dtype_backend(dtype_backend)
#     187 is_series = False
#
# ValueError: invalid error value specified

# %%
filedate = "2026-04-22"
filepath = f"logs/{filedate}.BIN"

reviewer = ArduPilotLogReviewer(
    filedate=filedate,
    filepath=filepath,
    MOTOR_RCOU_CH=MOTOR_RCOU_CH,
    auto_detect_flight=True,
    ESC_CONT_A=70,
    ESC_BURST_A=80,
    save_plots=True,
    show_plots=True,
    verbose=True
)

reviewer.plot_att()
reviewer.plot_vibes()
reviewer.plot_rcou()
reviewer.plot_esc()
reviewer.plot_bat()
reviewer.plot_imus()
reviewer.plot_powr()
reviewer.plot_compass_interference()
reviewer.plot_gps()
reviewer.plot_baro()
reviewer.save_summary()
# Out:
# Parsing logs/2026-04-22.BIN...
# Flight Window Detected: 249.2s - 322.2s (Duration: 73.0s)
# Plotting ATT...
# Saving CSV ATT_2026-04-22.csv...
# Saving Plot ATT_2026-04-22.png...
# Plotting VIBE...
# Saving CSV VIBE[0]_2026-04-22.csv...
# Saving CSV VIBE[1]_2026-04-22.csv...
# Saving CSV VIBE[2]_2026-04-22.csv...
# Saving Plot VIBE_2026-04-22.png...
# Plotting RCOU...
# Saving CSV RCOU_2026-04-22.csv...
# Saving Plot RCOU_2026-04-22.png...
# Plotting ESC...
# Saving CSV ESC[9].RPM_2026-04-22.csv...
# Saving CSV ESC[10].RPM_2026-04-22.csv...
# Saving CSV ESC[11].RPM_2026-04-22.csv...
# Saving Plot ESC_2026-04-22.png...
# Plotting BAT...
# Saving CSV BAT[0]_2026-04-22.csv...
# Saving Plot BAT_2026-04-22.png...
# Plotting IMU...
# Saving CSV IMU[0]_2026-04-22.csv...
# Saving CSV IMU[1]_2026-04-22.csv...
# Saving CSV IMU[2]_2026-04-22.csv...
# Saving Plot IMU_2026-04-22.png...
# Plotting POWR...
# Saving CSV POWR_2026-04-22.csv...
# Saving Plot POWR_2026-04-22.png...
# Plotting MAG...
# Saving CSV MAG[0]_2026-04-22.csv...
# Saving CSV MAG[1]_2026-04-22.csv...
# Saving Plot MAG_2026-04-22.png...
# Plotting GPS...
# Saving CSV GPS[0]_2026-04-22.csv...
# Saving Plot GPS_2026-04-22.png...
# Plotting BARO...
# Saving CSV BARO[0]_2026-04-22.csv...
# Saving CSV BARO[1]_2026-04-22.csv...
# Saving Plot BARO_2026-04-22.png...
# Generating Summary...
# Saving SUMMARY_2026-04-22.txt...
